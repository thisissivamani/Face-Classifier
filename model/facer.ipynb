# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./dataset/kalyani priyadarshan/Kalyani-Priyadarshan-19.jpg')
img.shape
# Out:
# (2448, 1632, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (2448, 1632)

# %%
gray
# Out:
# array([[27, 27, 27, ..., 57, 57, 57],
#        [27, 27, 27, ..., 57, 57, 57],
#        [27, 27, 27, ..., 57, 57, 57],
#        ...,
#        [17, 17, 17, ..., 44, 44, 44],
#        [17, 17, 17, ..., 44, 44, 44],
#        [17, 17, 17, ..., 44, 44, 44]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[669, 211, 385, 385]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (669, 211, 385, 385)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (385, 385, 3)

# %% [markdown]
# # (3) Preprocessing: Use wavelet transform as a feature for traning our model
# In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc
# Wavelet transform

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# You can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier
# (3) Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region
# Lets write a python function that can take input image and returns cropped image (if face and eyes >=2 are detected)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./dataset/kalyani_priyadarshan/Actress-Kalyani-Priyadarshan-Latest-Photoshoot-Stills-.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./dataset/kalyani_priyadarshan/Actress-Kalyani-Priyadarshan-Latest-Photoshoot-Stills-.jpg')
plt.imshow(cropped_image)

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/cropped',
#  './dataset/kalyani_priyadarshan',
#  './dataset/me',
#  './dataset/prabhas',
#  './dataset/YS_jagan']

# %% [markdown]
# # Go through all images in dataset folder and create cropped images for them. There will be cropped folder inside dataset folder after you run this code

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/kalyani_priyadarshan
# Generating cropped images in folder:  ./dataset/cropped/me
# Generating cropped images in folder:  ./dataset/cropped/prabhas
# Generating cropped images in folder:  ./dataset/cropped/YS_jagan

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'kalyani_priyadarshan': ['./dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan1.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan10.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan11.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan12.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan13.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan14.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan15.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan16.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan17.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan18.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan19.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan2.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan20.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan21.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan22.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan23.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan24.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan25.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan26.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan27.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan28.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan29.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan3.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan4.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan5.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan6.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan7.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan8.png',
#   './dataset/cropped/kalyani_priyadarshan\\kalyani_priyadarshan9.png'],
#  'me': ['./dataset/cropped/me\\me1.png',
#   './dataset/cropped/me\\me2.png',
#   './dataset/cropped/me\\me3.png',
#   './dataset/cropped/me\\me4.png',
#   './dataset/cropped/me\\me5.png',
#   './dataset/cropped/me\\me6.png',
#   './dataset/cropped/me\\me7.png',
#   './dataset/cropped/me\\me8.png'],
#  'prabhas': ['./dataset/cropped/prabhas\\prabhas1.png',
#   './dataset/cropped/prabhas\\prabhas10.png',
#   './dataset/cropped/prabhas\\prabhas11.png',
#   './dataset/cropped/prabhas\\prabhas12.png',
#   './dataset/cropped/prabhas\\prabhas13.png',
#   './dataset/cropped/prabhas\\prabhas14.png',
#   './dataset/cropped/prabhas\\prabhas15.png',
#   './dataset/cropped/prabhas\\prabhas16.png',
#   './dataset/cropped/prabhas\\prabhas17.png',
#   './dataset/cropped/prabhas\\prabhas18.png',
#   './dataset/cropped/prabhas\\prabhas19.png',
#   './dataset/cropped/prabhas\\prabhas2.png',
#   './dataset/cropped/prabhas\\prabhas20.png',
#   './dataset/cropped/prabhas\\prabhas21.png',
#   './dataset/cropped/prabhas\\prabhas22.png',
#   './dataset/cropped/prabhas\\prabhas23.png',
#   './dataset/cropped/prabhas\\prabhas24.png',
#   './dataset/cropped/prabhas\\prabhas3.png',
#   './dataset/cropped/prabhas\\prabhas4.png',
#   './dataset/cropped/prabhas\\prabhas5.png',
#   './dataset/cropped/prabhas\\prabhas6.png',
#   './dataset/cropped/prabhas\\prabhas7.png',
#   './dataset/cropped/prabhas\\prabhas8.png',
#   './dataset/cropped/prabhas\\prabhas9.png'],
#  'YS_jagan': ['./dataset/cropped/YS_jagan\\YS_jagan1.png',
#   './dataset/cropped/YS_jagan\\YS_jagan10.png',
#   './dataset/cropped/YS_jagan\\YS_jagan11.png',
#   './dataset/cropped/YS_jagan\\YS_jagan12.png',
#   './dataset/cropped/YS_jagan\\YS_jagan13.png',
#   './dataset/cropped/YS_jagan\\YS_jagan14.png',
#   './dataset/cropped/YS_jagan\\YS_jagan15.png',
#   './dataset/cropped/YS_jagan\\YS_jagan16.png',
#   './dataset/cropped/YS_jagan\\YS_jagan17.png',
#   './dataset/cropped/YS_jagan\\YS_jagan18.png',
#   './dataset/cropped/YS_jagan\\YS_jagan19.png',
#   './dataset/cropped/YS_jagan\\YS_jagan2.png',
#   './dataset/cropped/YS_jagan\\YS_jagan20.png',
#   './dataset/cropped/YS_jagan\\YS_jagan21.png',
#   './dataset/cropped/YS_jagan\\YS_jagan22.png',
#   './dataset/cropped/YS_jagan\\YS_jagan23.png',
#   './dataset/cropped/YS_jagan\\YS_jagan24.png',
#   './dataset/cropped/YS_jagan\\YS_jagan25.png',
#   './dataset/cropped/YS_jagan\\YS_jagan26.png',
#   './dataset/cropped/YS_jagan\\YS_jagan27.png',
#   './dataset/cropped/YS_jagan\\YS_jagan28.png',
#   './dataset/cropped/YS_jagan\\YS_jagan29.png',
#   './dataset/cropped/YS_jagan\\YS_jagan3.png',
#   './dataset/cropped/YS_jagan\\YS_jagan30.png',
#   './dataset/cropped/YS_jagan\\YS_jagan31.png',
#   './dataset/cropped/YS_jagan\\YS_jagan32.png',
#   './dataset/cropped/YS_jagan\\YS_jagan33.png',
#   './dataset/cropped/YS_jagan\\YS_jagan34.png',
#   './dataset/cropped/YS_jagan\\YS_jagan35.png',
#   './dataset/cropped/YS_jagan\\YS_jagan36.png',
#   './dataset/cropped/YS_jagan\\YS_jagan37.png',
#   './dataset/cropped/YS_jagan\\YS_jagan38.png',
#   './dataset/cropped/YS_jagan\\YS_jagan39.png',
#   './dataset/cropped/YS_jagan\\YS_jagan4.png',
#   './dataset/cropped/YS_jagan\\YS_jagan40.png',
#   './dataset/cropped/YS_jagan\\YS_jagan41.png',
#   './dataset/cropped/YS_jagan\\YS_jagan42.png',
#   './dataset/cropped/YS_jagan\\YS_jagan43.png',
#   './dataset/cropped/YS_jagan\\YS_jagan44.png',
#   './dataset/cropped/YS_jagan\\YS_jagan45.png',
#   './dataset/cropped/YS_jagan\\YS_jagan46.png',
#   './dataset/cropped/YS_jagan\\YS_jagan47.png',
#   './dataset/cropped/YS_jagan\\YS_jagan48.png',
#   './dataset/cropped/YS_jagan\\YS_jagan49.png',
#   './dataset/cropped/YS_jagan\\YS_jagan5.png',
#   './dataset/cropped/YS_jagan\\YS_jagan50.png',
#   './dataset/cropped/YS_jagan\\YS_jagan51.png',
#   './dataset/cropped/YS_jagan\\YS_jagan52.png',
#   './dataset/cropped/YS_jagan\\YS_jagan53.png',
#   './dataset/cropped/YS_jagan\\YS_jagan54.png',
#   './dataset/cropped/YS_jagan\\YS_jagan55.png',
#   './dataset/cropped/YS_jagan\\YS_jagan56.png',
#   './dataset/cropped/YS_jagan\\YS_jagan57.png',
#   './dataset/cropped/YS_jagan\\YS_jagan58.png',
#   './dataset/cropped/YS_jagan\\YS_jagan59.png',
#   './dataset/cropped/YS_jagan\\YS_jagan6.png',
#   './dataset/cropped/YS_jagan\\YS_jagan60.png',
#   './dataset/cropped/YS_jagan\\YS_jagan61.png',
#   './dataset/cropped/YS_jagan\\YS_jagan62.png',
#   './dataset/cropped/YS_jagan\\YS_jagan63.png',
#   './dataset/cropped/YS_jagan\\YS_jagan64.png',
#   './dataset/cropped/YS_jagan\\YS_jagan7.png',
#   './dataset/cropped/YS_jagan\\YS_jagan8.png',
#   './dataset/cropped/YS_jagan\\YS_jagan9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'kalyani_priyadarshan': 0, 'me': 1, 'prabhas': 2, 'YS_jagan': 3}

# %% [markdown]
# # Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X)
# Out:
# 125

# %%
len(X[0])
# Out:
# 4096

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (125, 4096)

# %% [markdown]
# # Data cleaning process is done. Now we are ready to train our model

# %% [markdown]
# We will use SVM with rbf kernel tuned with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.0.2

# %%
print(scikit-learn.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16188\680252270.py in <module>
# ----> 1 print(scikit-learn.__version__)
#
# NameError: name 'scikit' is not defined

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.75

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89         9
#            1       0.00      0.00      0.00         2
#            2       1.00      0.17      0.29         6
#            3       0.68      1.00      0.81        15
#
#     accuracy                           0.75        32
#    macro avg       0.64      0.51      0.50        32
# weighted avg       0.76      0.75      0.68        32
# C:\Users\sivam\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\sivam\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\sivam\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.830409
# 1        random_forest    0.689474
# 2  logistic_regression    0.701754
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 5}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=5, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.90625

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.8125

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.96875

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 9,  0,  0,  0],
#        [ 0,  1,  1,  0],
#        [ 0,  0,  4,  2],
#        [ 0,  0,  0, 15]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'kalyani_priyadarshan': 0, 'me': 1, 'prabhas': 2, 'YS_jagan': 3}

# %% [markdown]
# # Save the trained model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\sivam\anaconda3\lib\site-packages (1.1.0)
# ['saved_model.pkl']

# %% [markdown]
# # Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
